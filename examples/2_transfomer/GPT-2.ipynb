# %%
! pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/wick/language_models/.venv/lib/python3.13/site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipywidgets) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
# Load GPT-2 small (decoder-only Transformer)
model_name = "gpt2"  # ~124M parameters
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# %%
# Set model to evaluation mode
model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# Example prompt
prompt = "ChatGPT explains things"

# %%
# Encode prompt
input_ids = tokenizer.encode(prompt, return_tensors="pt")

# %%
# Generate tokens autoregressively with pad_token_id explicitly set
output_ids = model.generate(
    input_ids,
    max_new_tokens=10,
    do_sample=True,
    top_k=50,
    pad_token_id=tokenizer.eos_token_id  # Fixes warning
)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
# Decode to text
generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("Prompt:", prompt)
print("Generated text:", generated_text)
# Out:
# Prompt: ChatGPT explains things
# Generated text: ChatGPT explains things a little better on how to make a list of
